# %%
import warnings
warnings.filterwarnings("ignore")

# %%
import pandas as P

# %%
D = P.read_csv ("Fuel Consumption Dataset Clean.csv")

# %%
print(D.columns)
# Out:
# Index(['Unnamed: 0', 'Model Year', 'Make', 'Model', 'Vehicle Class',
#        'Engine Size(L)', 'Cylinders', 'Transmission', 'Fuel Type',
#        'Fuel Consumption (City (L/100 km)', 'Fuel Consumption(Hwy (L/100 km))',
#        'Fuel Consumption(Comb (L/100 km))', 'Fuel Consumption(Comb (mpg))',
#        'CO2 Emissions(g/km)', 'CO2 Rating', 'Smog Rating',
#        'Fuel Efficiency City', 'Fuel Efficiency Highway',
#        'Fuel Efficiency Combined', 'Engine Group', 'Efficiency Ratio City',
#        'Efficiency Ratio Highway', 'Efficiency Ratio Combined',
#        'Emission Rate CO2 level'],
#       dtype='object')

# %%
print(D.dtypes)
# Out:
# Unnamed: 0                             int64
# Model Year                             int64
# Make                                   int64
# Model                                  int64
# Vehicle Class                          int64
# Engine Size(L)                       float64
# Cylinders                              int64
# Transmission                           int64
# Fuel Type                              int64
# Fuel Consumption (City (L/100 km)    float64
# Fuel Consumption(Hwy (L/100 km))     float64
# Fuel Consumption(Comb (L/100 km))    float64
# Fuel Consumption(Comb (mpg))           int64
# CO2 Emissions(g/km)                    int64
# CO2 Rating                             int64
# Smog Rating                            int64
# Fuel Efficiency City                 float64
# Fuel Efficiency Highway              float64
# Fuel Efficiency Combined             float64
# Engine Group                           int64
# Efficiency Ratio City                float64
# ...

# %%
print(D.shape)
# Out:
# (946, 24)

# %%
X = D.drop(["Fuel Consumption(Comb (L/100 km))"] , axis = 1)
Y = D["Fuel Consumption(Comb (L/100 km))"]

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error , r2_score , mean_absolute_error

# %%
X_Train , X_Test , Y_Train , Y_Test = train_test_split(X , Y , test_size = 0.2 , random_state = 42)
print(X.shape , X_Train.shape , X_Test.shape , Y_Train.shape , Y_Test.shape)
# Out:
# (946, 23) (756, 23) (190, 23) (756,) (190,)

# %%
M = LinearRegression ()
F = M.fit (X_Train , Y_Train)

# %%
PRE = M.predict (X_Test)
print(PRE)
# Out:
# [13.10268818 10.65491101 13.46745045 14.42667704  9.38143766 11.8351539
#   9.38362752 13.91453871 10.24611319 13.88488927 13.33098295 16.18816855
#   7.63786957 13.83380948 10.49218171 13.72535666 13.9929722  14.72768833
#   8.40973361 10.77011012  8.21321742  8.550794   14.30613906 14.11504858
#   7.1804981  10.19794394 12.21867913  4.58805099  9.09819363 11.60069053
#   7.18435576 12.99555895 11.74110096 11.79171492  9.589687   11.13977861
#  13.7927936   7.80062167 14.09060975  9.09636492 10.69301277  8.97125742
#   9.29598515 12.0907563  15.24214653 11.27997131 10.9748975  11.84911124
#  10.15759097  8.5845992  16.21758514 11.59854931 14.13573051  8.81873735
#  14.31748699 10.30256842 13.85958459 10.2319965   8.00274577  7.88232868
#  12.07934586  4.47199695 14.79450146 11.65872114 12.28345317  9.21091231
#   9.50846572  9.39498355 11.49071144  9.6618519  13.91327502 13.81078819
#   8.09720385  7.852799   11.97621871 12.72955004 12.95772031 11.59870075
# ...

# %%
import numpy as NUM
R2 = r2_score (Y_Test , PRE)
print(R2 * 100 , "%")
MSE = mean_squared_error (Y_Test , PRE)
print(MSE)
MAE = mean_absolute_error (Y_Test , PRE)
print(MAE)
RMSE = NUM.sqrt (MSE)
print(RMSE)
# Out:
# 99.98928923023949 %
# 0.0008937739494172359
# 0.02345927445906335
# 0.029896052405246346

# %%
import matplotlib.pyplot as PLOT
PLOT.scatter (Y_Test , PRE)
PLOT.plot ([Y_Test.min() , Y_Test.max()] , [Y_Test.min() , Y_Test.max()])
PLOT.show ()

# %%
print(D.columns)
print("\n")
print(D.shape)
# Out:
# Index(['Unnamed: 0', 'Model Year', 'Make', 'Model', 'Vehicle Class',
#        'Engine Size(L)', 'Cylinders', 'Transmission', 'Fuel Type',
#        'Fuel Consumption (City (L/100 km)', 'Fuel Consumption(Hwy (L/100 km))',
#        'Fuel Consumption(Comb (L/100 km))', 'Fuel Consumption(Comb (mpg))',
#        'CO2 Emissions(g/km)', 'CO2 Rating', 'Smog Rating',
#        'Fuel Efficiency City', 'Fuel Efficiency Highway',
#        'Fuel Efficiency Combined', 'Engine Group', 'Efficiency Ratio City',
#        'Efficiency Ratio Highway', 'Efficiency Ratio Combined',
#        'Emission Rate CO2 level'],
#       dtype='object')
#
#
# (946, 24)

# %%
PRE_T = M.predict ([[198 , 2022 , 9 , 598 , 6 , 5.3 , 8 , 1 , 1 , 21.5 , 16 , 15 , 321 , 3 , 3 , 0.04 , 0.06 , 0.05 , 4 , 0.008 , 0.01 , 0.009 , 0.50]])
print(PRE_T)
# Out:
# [18.88974536]

# %%
print(D.columns)
print("\n")
print(D.shape)
# Out:
# Index(['Unnamed: 0', 'Model Year', 'Make', 'Model', 'Vehicle Class',
#        'Engine Size(L)', 'Cylinders', 'Transmission', 'Fuel Type',
#        'Fuel Consumption (City (L/100 km)', 'Fuel Consumption(Hwy (L/100 km))',
#        'Fuel Consumption(Comb (L/100 km))', 'Fuel Consumption(Comb (mpg))',
#        'CO2 Emissions(g/km)', 'CO2 Rating', 'Smog Rating',
#        'Fuel Efficiency City', 'Fuel Efficiency Highway',
#        'Fuel Efficiency Combined', 'Engine Group', 'Efficiency Ratio City',
#        'Efficiency Ratio Highway', 'Efficiency Ratio Combined',
#        'Emission Rate CO2 level'],
#       dtype='object')
#
#
# (946, 24)

# %%
E = D["Engine Size(L)"]
C = D["Cylinders"]
print(E)
print("\n")
print(C)
print("\n")
def O (E , C) :
  if E > 3.0 :
    return "As Engine Size is Big , Fuel Consumption is more"
  elif C > 6 :
    return "As Cylinder Size is Big , Fuel Consumption is more"
  else :
    return "Fuel Consumption is Efficient"
print(O (8 , 2))
# Out:
# 0      2.4
# 1      3.5
# 2      2.0
# 3      2.0
# 4      2.0
#       ...
# 941    2.0
# 942    2.0
# 943    2.0
# 944    2.0
# 945    2.0
# Name: Engine Size(L), Length: 946, dtype: float64
#
#
# 0      4
# 1      6
# 2      4
# 3      4
# 4      4
#       ..
# 941    4
# 942    4
# 943    4
# 944    4
# 945    4
# Name: Cylinders, Length: 946, dtype: int64
#
#
# As Engine Size is Big , Fuel Consumption is more
