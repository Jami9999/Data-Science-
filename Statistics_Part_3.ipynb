# %%
Total_Outcomes_Toss = 2
P_H = 1 / 2
print(P_H * 100 , "%")
# Out:
# 50.0 %

# %%
P_Dice = 1 / 6
print(P_Dice * 100 , "%")
# Out:
# 16.666666666666664 %

# %%
Dice_Even = 3
P_D_E = Dice_Even / 6
print(P_D_E * 100 , "%")
# Out:
# 50.0 %

# %%
P_Two_Coins = 1 / 4
print(P_Two_Coins * 100 , "%")
# Out:
# 25.0 %

# %%
P_At_least_One_Head = 3 / 4
print(P_At_least_One_Head * 100 , "%")
# Out:
# 75.0 %

# %%
Even = 5
Total = 10
P = Even / Total
print (P * 100 , "%")
# Out:
# 50.0 %

# %%
Probability_Card = 26 / 52
print(Probability_Card * 100 , "%")
# Out:
# 50.0 %

# %%
Multiple_Dice_P = 6 / 36
print(Multiple_Dice_P * 100 , "%")
# Out:
# 16.666666666666664 %

# %%
P_AB = 0.2
P_B = 0.5
Conditional_Probability = (P_AB / P_B) * 100
print(Conditional_Probability , "%")
# Out:
# 40.0 %

# %%
PB = 0.3
PA = 0.8
PAB = 0.5
Probability_BT = (PAB * PB) / PB
print(Probability_BT * 100 , "%")
# Out:
# 50.0 %

# %%
O = 0.5
S = 0.4
O_S = 0.7
Probability_Spam_D = (O_S * O) / S * 100
print(Probability_Spam_D , "%")
# Out:
# 87.49999999999999 %

# %%
PA = 0.5
PB = 0.6
P_Independent_Event = (PA * PB) * 100
print(P_Independent_Event , "%")
# Out:
# 30.0 %

# %%
PA = 0.5
PAB = 0.4
Probability_Dependent_Event = (PA * PAB) * 100
print(Probability_Dependent_Event , "%")
# Out:
# 20.0 %

# %%
PA = 0.7
Complement_P = 1 - PA
print(Complement_P * 100 , "%")
# Out:
# 30.000000000000004 %

# %%
Fail = 0.5
Probability_At_Least_One_Sucess = (1 - (Fail ** 3)) * 100
print(Probability_At_Least_One_Sucess , "%")
# Out:
# 87.5 %

# %%
import numpy as N
DATA = [1 , 2 , 2 , 3 , 3 , 3]
V_C = N.unique (DATA)
Probability = ((V_C / len (DATA)) * 100)
print(dict (zip (V_C , Probability)))
# Out:
# {np.int64(1): np.float64(16.666666666666664), np.int64(2): np.float64(33.33333333333333), np.int64(3): np.float64(50.0)}

# %%
from scipy.stats import binom
N = 5
P = 0.5
K = 3
Binomial_Distribution = binom.pmf (K , N , P)
print(Binomial_Distribution * 100 , "%")
# Out:
# 31.249999999999982 %

# %%
import numpy as N
V = [0 , 1]
P = [0.4 , 0.6]
E = N.dot (V , P)
print(E * 100 , "%")
# Out:
# 60.0 %

# %%
import numpy as N
D = [1 , 2 , 3 , 4]
Varience = N.var (D)
print(Varience)
# Out:
# 1.25

# %%
from scipy.stats import norm
M = 0
S = 1
N = norm.cdf(1 , M , S)
print(N)
# Out:
# 0.8413447460685429

# %%
import numpy as N
X = N.random.random (10000)
Y = N.random.random (10000)
I = N.sum ((X * X + Y * Y) <= 1)
PI = I / 10000
print(PI)
# Out:
# 0.7835

# %%
S = 0.4
H = 0.6
WS = 0.7
WH = 0.2
PS = S * WS
PH = H * WH
print(PS)
print(PH)
if PS > PH :
  print("Spam")
else :
  print ("No Spam")
# Out:
# 0.27999999999999997
# 0.12
# Spam

# %%
F = 0.02
HAF = 0.9
H = 0.1
Result = (HAF * F) / H
print(Result)
# Out:
# 0.18000000000000002

# %%
import numpy as N
A = N.random.binomial (1 , 0.63 , 1000)
B = N.random.binomial (1 , 0.55 , 313)
MA = A.mean ()
MB = B.mean ()
print(MA , MB)
# Out:
# 0.633 0.536741214057508

# %%
V = 100
B = 63
CR = V / B
print(CR)
# Out:
# 1.5873015873015872
