# %%
import pandas as P
import matplotlib.pyplot as PLOT
import warnings
warnings.filterwarnings("ignore")
import numpy as NUM
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score

# %%
Data = {
    "Engine Size" : [1.0 , 1.5 , 2.0 , 2.5 , 3.0] ,
    "Fuel Consumption" : [20 , 18 , 15 , 12 , 10]
}
DF = P.DataFrame (Data)
print(DF)
# Out:
#    Engine Size  Fuel Consumption
# 0          1.0                20
# 1          1.5                18
# 2          2.0                15
# 3          2.5                12
# 4          3.0                10

# %%
CORR = DF.corr ()
print(CORR)
# Out:
#                   Engine Size  Fuel Consumption
# Engine Size          1.000000         -0.997054
# Fuel Consumption    -0.997054          1.000000

# %%
X = DF[["Engine Size"]]
Y = DF["Fuel Consumption"]
X_Train , X_Test , Y_Train , Y_Test = train_test_split (X , Y , test_size = 0.2 , random_state = 42)

# %%
M = LinearRegression ()
M.fit (X_Train , Y_Train)
# Out:
# LinearRegression()

# %%
PRE = M.predict (X_Test)
print(PRE)
# Out:
# [17.42857143]

# %%
R2 = r2_score (Y_Test , PRE)
print(R2)
# Out:
# nan

# %%
PLOT.scatter (X_Train , Y_Train)
PLOT.show ()

# %%
PLOT.scatter (X_Test , Y_Test)
PLOT.show ()

# %%
PREDICTION = M.predict ([[1.8] , [2.2] , [2.8]])
print(PREDICTION)
# Out:
# [15.90285714 13.86857143 10.81714286]
