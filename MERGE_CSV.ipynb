# %%
import pandas as P

# %%
D1 = P.read_csv ("1.csv")
D2 = P.read_csv ("2.csv")
D3 = P.read_csv ("3.csv")
D4 = P.read_csv ("4.csv")

# %%
Merged = P.concat ([D1 , D2 , D3 , D4] , ignore_index = False)

# %%
Save_File = Merged.to_csv ("European Football Result.csv")
