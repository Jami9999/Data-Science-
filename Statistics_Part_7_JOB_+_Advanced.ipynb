# %%
import pandas as P
import warnings
warnings.filterwarnings('ignore')
import matplotlib.pyplot as PLOT
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score

# %%
Data = {
    "Experience" : [1 , 2 , 3 , 4 , 5] ,
    "Education Level" : [1 , 2 , 2 , 3 , 3] ,
    "Salary" : [20000 , 30000 , 40000 , 50000 , 60000]
}
DF = P.DataFrame (Data)
print(DF)
# Out:
#    Experience  Education Level  Salary
# 0           1                1   20000
# 1           2                2   30000
# 2           3                2   40000
# 3           4                3   50000
# 4           5                3   60000

# %%
X = DF[["Experience" , "Education Level"]]
Y = DF["Salary"]
X_Train , X_Test , Y_Train , Y_Test = train_test_split (X , Y , test_size = 0.2 , random_state = 42)

# %%
M_2 = LinearRegression ()
M_2.fit (X_Train , Y_Train)
# Out:
# LinearRegression()

# %%
PRED = M_2.predict (X_Test)
print(PRED)
# Out:
# [30000.]

# %%
R2_2 = r2_score (Y_Test , PRED)
print(R2_2)
# Out:
# nan

# %%
P_3 = M_2.predict ([[6 , 3]])
print(P_3)
# Out:
# [70000.]

# %%
Residuals = Y_Test - P_3
print(Residuals)
# Out:
# 1   -40000.0
# Name: Salary, dtype: float64

# %%
PLOT.scatter (P_3 , Residuals)
PLOT.axhline (y = 0)
PLOT.show ()

# %%
Data = {
    "Ads" : [10 , 20 , 30 , 40 , 50] ,
    "Sales" : [100 , 200 , 300 , 400 , 500]
}
DF = P.DataFrame (Data)
print(DF)
print("\n")
X = DF [["Ads"]]
Y = DF ["Sales"]
print(X)
print(Y)
print("\n")
X_Train , X_Test , Y_Train , Y_Test = train_test_split (X , Y , test_size = 0.2 , random_state = 42)
print("\n")
M = LinearRegression ()
print ("\n")
F = M.fit (X_Train , Y_Train)
print("\n")
PRE = M.predict ([[63]])
print(PRE)
# Out:
#    Ads  Sales
# 0   10    100
# 1   20    200
# 2   30    300
# 3   40    400
# 4   50    500
#
#
#    Ads
# 0   10
# 1   20
# 2   30
# 3   40
# 4   50
# 0    100
# 1    200
# 2    300
# 3    400
# 4    500
# Name: Sales, dtype: int64
#
#
#
#
#
#
#
#
# [630.]

# %%
Data = {
    "Area" : [1000 , 1200 , 1500 , 1800 , 2000] ,
    "Bedrooms" : [2 , 3 , 3 , 4 , 4] ,
    "Price" : [200000 , 250000 , 300000 , 350000 , 400000]
}
DF = P.DataFrame (Data)
print(DF)
print("\n")
X = DF [["Area" , "Bedrooms"]]
Y = DF ["Price"]
print(X)
print("\n")
print(Y)
X_Train , X_Test , Y_Train , Y_Test = train_test_split (X , Y , test_size = 0.2 , random_state = 42)
print (X_Train)
print("\n")
print(X_Test)
print("\n")
print(Y_Train)
print("\n")
print(Y_Test)
print("\n")
M = LinearRegression ()
print(M)
print("\n")
F = M.fit (X_Train , Y_Train)
print(F)
print("\n")
PRE = M.predict ([[1700 , 3]])
print(PRE)
# Out:
#    Area  Bedrooms   Price
# 0  1000         2  200000
# 1  1200         3  250000
# 2  1500         3  300000
# 3  1800         4  350000
# 4  2000         4  400000
#
#
#    Area  Bedrooms
# 0  1000         2
# 1  1200         3
# 2  1500         3
# 3  1800         4
# 4  2000         4
#
#
# 0    200000
# 1    250000
# 2    300000
# 3    350000
# 4    400000
# Name: Price, dtype: int64
#    Area  Bedrooms
# 4  2000         4
# 2  1500         3
# 0  1000         2
# 3  1800         4
#
#
#    Area  Bedrooms
# 1  1200         3
#
#
# 4    400000
# 2    300000
# 0    200000
# 3    350000
# Name: Price, dtype: int64
#
#
# 1    250000
# Name: Price, dtype: int64
#
#
# LinearRegression()
#
#
# LinearRegression()
#
#
# [350000.]
