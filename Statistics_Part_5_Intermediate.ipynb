# %%
import warnings
warnings.filterwarnings('ignore')
import numpy as N

# %%
from scipy import stats
Boys = [70 , 75 , 80 ,85]
Girls = [60 , 65 , 70 , 72]
TT_1 , PV_1 = stats.ttest_ind (Boys , Girls)
print(PV_1)
print(TT_1)
# Out:
# 0.042960679132534374
# 2.559100712767547

# %%
from scipy import stats
Before = [50 , 55 , 60]
After = [60 , 65 , 70]
TT_2 , PV_2 = stats.ttest_rel (Before , After)
print (PV_2)
print(TT_2)
# Out:
# 0.0
# -inf

# %%
OLD = [100 , 120 , 130]
NEW = [140 , 150 , 160]
TT_3 , PV_3 = stats.ttest_ind (OLD , NEW)
print(TT_3)
print(PV_3)
# Out:
# -3.162277660168379
# 0.034109423167409635

# %%
Machine_1 = [20 , 22 , 19 , 24]
Machine_2 = [30 , 32 , 31 , 29]
TT_4 , PV_4 = stats.ttest_ind (Machine_1 , Machine_2)
print(TT_4)
print(PV_4)
# Out:
# -7.210224807324103
# 0.00036051304970422177

# %%
DS_A = [30 , 32 , 35]
DS_B = [40 , 42 , 45]
TT_5 , PV_5 = stats.ttest_ind (DS_A , DS_B)
print(PV_5)
print(TT_5)
# Out:
# 0.008239642742274787
# -4.866642633922876

# %%
TT_6 , PV_6 = stats.ttest_1samp ([60 , 65 , 70] , 50)
print(PV_6)
print(PV_6 / 2)
print(TT_6)
# Out:
# 0.035098718645984656
# 0.017549359322992328
# 5.196152422706631

# %%
A = [10 , 12 , 11]
B = [15 , 18 , 20]
TT_7 , PV_7 = stats.ttest_ind (A , B)
print(PV_7)
print(PV_7 / 2)
print(TT_7)
# Out:
# 0.013011948880740599
# 0.0065059744403702996
# -4.264014327112209

# %%
O = [0 , 1 , 0 , 1 , 0]
N = [1 , 1 , 1 , 1 , 0]
TT_8 , PV_8 = stats.ttest_ind (O , N)
print(PV_8)
print(PV_8 / 2)
print(TT_8)
# Out:
# 0.24150397191306
# 0.12075198595653
# -1.2649110640673518

# %%
import numpy as N
Small = N.random.normal (26 , 10 , 40)
Large = N.random.normal (30 , 2 , 80)
print(Small)
print("\n")
print(Large)
print("\n")
print(N.mean (Small))
print("\n")
print(N.mean (Large))
# Out:
# [23.00333146 36.43568423 34.74341971 19.25029918 31.42730556 24.63986454
#  36.51619745 32.69043266 15.50410161 15.093036   23.66023515 30.50155502
#   8.990478   28.87461783 24.22247309 18.0849021  21.26723096 12.20124343
#  19.01692667 19.73204369 34.85221849 35.2002717  23.46912272  7.75748069
#  14.43804354 11.01904934 24.37604986 26.97422331 31.74393713 50.21424298
#  23.67575697 24.81963606 29.69814874 16.29292373 18.7370343  19.67983653
#   8.72379573 18.81520625 21.24413617 31.63294873]
#
#
# [27.84351248 32.50463495 29.65792739 29.1707016  28.03632472 30.31008708
#  25.72174398 31.88505708 29.01627539 32.03724876 26.48482369 28.9154097
#  32.4343953  27.79127952 33.49760333 26.14906602 28.01912156 30.09039036
#  29.78713083 29.98527518 28.35589314 30.25438057 29.84586971 28.44934476
#  31.10175646 33.03840738 28.66664156 28.19744331 30.1437755  25.97196694
#  30.83644929 31.22357409 29.92846119 28.14821998 31.89165322 29.45519249
# ...
